# %%
import numpy as np
import pandas as pd
import matplotlib

import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
matplotlib.rc('text', usetex=True)
matplotlib.rcParams.update({"font.size":16})
import os
import sys

sys.path.append(os.path.abspath('../..'))
from modules import io

# %%
CASE_DIR = "/home/marsdenlab/projects/SV/UQ/data/2_vessel_data/medium"
#CSV_FILE = "aorta_path"
CSV_FILE = 'right_iliac_path'
OUT_DIR = "/home/marsdenlab/projects/SV/UQ/data/2_vessel_data/plots/medium"

dirs = os.listdir(CASE_DIR)
df_fns = [CASE_DIR+'/'+d+'/'+CSV_FILE+'.csv' for d in dirs]

dataframes = []
for d in df_fns:
    if not os.path.exists(d): continue
    df_tmp = pd.read_csv(d)
    dataframes.append(df_tmp)
    
df = pd.concat(dataframes)

# %%
COORD_IDS  = df['coord_id'].unique()
label      = 'velocity_00400_1'
color      = 'g'
plot_label = label.replace('_',' ')
for c in COORD_IDS:
    data = df.loc[df['coord_id']==c][label]

    plt.figure()
    plt.hist(data.values,bins=10, label=plot_label, color=color)
    plt.xlabel(plot_label)
    plt.ylabel('coord id = {}'.format(c))
    plt.legend()
    
    plt.savefig(OUT_DIR+'/'+CSV_FILE+'_'+label+str(c)+'.png',dpi=300)
    plt.show()
# Out:
# /home/marsdenlab/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py:6735: RuntimeWarning: All-NaN slice encountered
#   xmin = min(xmin, np.nanmin(xi))
# /home/marsdenlab/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py:6736: RuntimeWarning: All-NaN slice encountered
#   xmax = max(xmax, np.nanmax(xi))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-3251a92a06d6> in <module>
#       7
#       8     plt.figure()
# ----> 9     plt.hist(data.values,bins=10, label=plot_label, color=color)
#      10     plt.xlabel(plot_label)
#      11     plt.ylabel('coord id = {}'.format(c))
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
# ...
