# %%
import sys
import os

sys.path.append(os.path.abspath('../..'))
from modules import io
#0110
CASE     = "0110"
#SUB_DIRS     = ["aorta","right_iliac"]
#SIMS     = ["sim_steady","sim_steady_real_out","sim_wom_rcr","sim_wom_rcr_real"]

SUB_DIRS = ["aorta.0","aorta.1","right_iliac.1"]
SIMS     = ["sim_wom_rcr_real"]

#0144
# CASE     = "0144"
# SUB_DIRS = ["aorta","ext_iliac_left","SMA",
#                 "celiac_hepatic","renal_right","renal_left"]
# SIMS     = ["wom_rcr_real"]

#0119


#############################################
MAIN_DIR = "/media/marsdenlab/Data1/UQ/"+CASE
GENS     = ["1","2","3","4"]
MESHES   = ["coarse","medium","fine"]
SUB_SUB_DIRS = ["tube","stats","plots"]

path = os.path.join(MAIN_DIR,CASE)
io.mkdir(path)

for S in SIMS:
    path = os.path.join(MAIN_DIR,S)
    io.mkdir(path)
    io.mkdir(path+'/csv')
    for G in GENS:
        path = os.path.join(MAIN_DIR,S,G)
        io.mkdir(path)
        
        for M in MESHES:
            path = os.path.join(MAIN_DIR,S,G,M)
            io.mkdir(path)
            io.mkdir(path+'/vtus')
            
            for SS in SUB_DIRS:
                path = os.path.join(MAIN_DIR,S,G,M,SS)
                io.mkdir(path)
                
                for SSS in SUB_SUB_DIRS:
                    path = os.path.join(MAIN_DIR,S,G,M,SS,SSS)
                    io.mkdir(path)
                    print(path)
# Out:
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/1/coarse/aorta.0/tube
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/1/coarse/aorta.0/stats
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/1/coarse/aorta.0/plots
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/1/coarse/aorta.1/tube
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/1/coarse/aorta.1/stats
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/1/coarse/aorta.1/plots
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/1/coarse/right_iliac.1/tube
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/1/coarse/right_iliac.1/stats
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/1/coarse/right_iliac.1/plots
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/1/medium/aorta.0/tube
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/1/medium/aorta.0/stats
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/1/medium/aorta.0/plots
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/1/medium/aorta.1/tube
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/1/medium/aorta.1/stats
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/1/medium/aorta.1/plots
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/1/medium/right_iliac.1/tube
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/1/medium/right_iliac.1/stats
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/1/medium/right_iliac.1/plots
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/1/fine/aorta.0/tube
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/1/fine/aorta.0/stats
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/1/fine/aorta.0/plots
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/1/fine/aorta.1/tube
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/1/fine/aorta.1/stats
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/1/fine/aorta.1/plots
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/1/fine/right_iliac.1/tube
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/1/fine/right_iliac.1/stats
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/1/fine/right_iliac.1/plots
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/2/coarse/aorta.0/tube
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/2/coarse/aorta.0/stats
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/2/coarse/aorta.0/plots
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/2/coarse/aorta.1/tube
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/2/coarse/aorta.1/stats
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/2/coarse/aorta.1/plots
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/2/coarse/right_iliac.1/tube
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/2/coarse/right_iliac.1/stats
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/2/coarse/right_iliac.1/plots
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/2/medium/aorta.0/tube
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/2/medium/aorta.0/stats
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/2/medium/aorta.0/plots
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/2/medium/aorta.1/tube
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/2/medium/aorta.1/stats
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/2/medium/aorta.1/plots
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/2/medium/right_iliac.1/tube
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/2/medium/right_iliac.1/stats
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/2/medium/right_iliac.1/plots
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/2/fine/aorta.0/tube
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/2/fine/aorta.0/stats
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/2/fine/aorta.0/plots
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/2/fine/aorta.1/tube
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/2/fine/aorta.1/stats
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/2/fine/aorta.1/plots
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/2/fine/right_iliac.1/tube
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/2/fine/right_iliac.1/stats
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/2/fine/right_iliac.1/plots
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/3/coarse/aorta.0/tube
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/3/coarse/aorta.0/stats
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/3/coarse/aorta.0/plots
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/3/coarse/aorta.1/tube
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/3/coarse/aorta.1/stats
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/3/coarse/aorta.1/plots
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/3/coarse/right_iliac.1/tube
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/3/coarse/right_iliac.1/stats
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/3/coarse/right_iliac.1/plots
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/3/medium/aorta.0/tube
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/3/medium/aorta.0/stats
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/3/medium/aorta.0/plots
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/3/medium/aorta.1/tube
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/3/medium/aorta.1/stats
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/3/medium/aorta.1/plots
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/3/medium/right_iliac.1/tube
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/3/medium/right_iliac.1/stats
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/3/medium/right_iliac.1/plots
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/3/fine/aorta.0/tube
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/3/fine/aorta.0/stats
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/3/fine/aorta.0/plots
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/3/fine/aorta.1/tube
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/3/fine/aorta.1/stats
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/3/fine/aorta.1/plots
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/3/fine/right_iliac.1/tube
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/3/fine/right_iliac.1/stats
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/3/fine/right_iliac.1/plots
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/4/coarse/aorta.0/tube
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/4/coarse/aorta.0/stats
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/4/coarse/aorta.0/plots
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/4/coarse/aorta.1/tube
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/4/coarse/aorta.1/stats
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/4/coarse/aorta.1/plots
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/4/coarse/right_iliac.1/tube
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/4/coarse/right_iliac.1/stats
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/4/coarse/right_iliac.1/plots
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/4/medium/aorta.0/tube
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/4/medium/aorta.0/stats
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/4/medium/aorta.0/plots
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/4/medium/aorta.1/tube
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/4/medium/aorta.1/stats
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/4/medium/aorta.1/plots
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/4/medium/right_iliac.1/tube
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/4/medium/right_iliac.1/stats
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/4/medium/right_iliac.1/plots
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/4/fine/aorta.0/tube
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/4/fine/aorta.0/stats
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/4/fine/aorta.0/plots
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/4/fine/aorta.1/tube
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/4/fine/aorta.1/stats
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/4/fine/aorta.1/plots
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/4/fine/right_iliac.1/tube
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/4/fine/right_iliac.1/stats
# /media/marsdenlab/Data1/UQ/0110/sim_wom_rcr_real/4/fine/right_iliac.1/plots
