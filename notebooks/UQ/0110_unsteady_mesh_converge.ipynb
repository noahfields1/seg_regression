# %%
import numpy as np
import pandas as pd
import matplotlib

import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
matplotlib.rc('text', usetex=True)
matplotlib.rcParams.update({"font.size":16})
import os
import sys

sys.path.append(os.path.abspath('../..'))
from modules import io

# %%
paths = [
    "aorta.0",
    "aorta.1",
    "right_iliac.1"
]

CASES = [
    "sim_wom_rcr_real"
]

meshes = [
    "coarse",
]

quants   = [
 "pressure_0",
 "vWSS_3_boundary",
 "velocity_3"
]

generation = 1

models   = list(range(50))
dt       = 0.02

tups = []

for case in CASES:
    for p in paths:
            for m in meshes:
                    CSV    = "/media/marsdenlab/Data1/UQ/0110/"+case+"/csv/"+'/'+p+".csv"
                    
                    OUTPUT = "/media/marsdenlab/Data1/UQ/0110/"+case+"/"+str(generation)+"/"+m+"/"+p+"/tube"
                    io.mkdir(OUTPUT)
                    OUTPUT = OUTPUT+'/'+m
                    io.mkdir(OUTPUT)
                    
                    df = pd.read_csv(CSV)
                    df = df.loc[df['mesh']==m]
                    
                    
                    
                    tups.append( (case,p,m,df,OUTPUT) )

# %%
for t in tups:
    case,path,mesh,df,OUTPUT = t
    
    for q in quants:
        series_x = []
        series_y = []
        for m in models:
            data = df.loc[(df['model'] == m) & (df['generation'] == generation)]

            if data.shape[0] == 0: continue

            y = data[q].values
            x = data['time'].values*dt

            series_x.append(x)
            series_y.append(y)

        Y = np.array(series_y)
        X = np.array(series_x)
        
        label = q.split('_')[0]
        
        plt.figure(figsize=(8,8))
        plt.plot(X.T,Y.T, color='b')
        plt.xlabel("time")
        plt.ylabel(label)
        plt.legend()
        plt.savefig(OUTPUT+'/'+q+'.png',dpi=300)
        plt.savefig(OUTPUT+'/'+q+'.pdf',dpi=200)
        
        plt.show()
        plt.close()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
for t in tups:
    case,path,mesh,df,OUTPUT = t
    
    for q in quants:
        series_x = []
        series_y = []
        for m in models:
            data = df.loc[(df['model'] == m) & (df['generation']==generation)]
            if data.shape[0] == 0: continue
            y = data[q].values
            x = data['time'].values*dt

            series_x.append(x)
            series_y.append(y)

        Y = np.array(series_y)
        X = np.array(series_x)

        mu  = np.mean(Y,axis=0)
        std = np.std(Y,axis=0)*2
        
        label = q.split('_')[0]
        
        plt.figure(figsize=(8,8))
        plt.errorbar(x,y=mu, yerr=std, fmt='o')
        plt.xlabel("time")
        plt.ylabel(label)
        plt.legend()
        plt.savefig(OUTPUT+'/'+q+'_err.png',dpi=300)
        plt.savefig(OUTPUT+'/'+q+'_err.pdf',dpi=200)
        
        plt.show()
        plt.close()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
for t in tups:
    case,path,mesh,df,OUTPUT = t
    
    for q in quants:
        series_x = []
        series_y = []
        for m in models:
            data = df.loc[(df['model'] == m)]
            if data.shape[0] == 0: continue
            y = data[q].values
            x = data['time'].values*dt

            series_x.append(x)
            series_y.append(y)

        Y = np.array(series_y)
        X = np.array(series_x)

        mu  = np.mean(Y,axis=0)
        std = np.std(Y,axis=0)
        std_rel = std/mu
        label = q.split('_')[0]
        
        plt.figure(figsize=(8,8))
        plt.plot(x,std_rel,marker='o',linestyle='')
        plt.xlabel("time")
        plt.ylabel(label)
        plt.ylim(0,1)
        plt.legend()
        plt.savefig(OUTPUT+'/'+q+'_std.png',dpi=300)
        plt.savefig(OUTPUT+'/'+q+'_std.pdf',dpi=200)
        
        plt.show()
        plt.close()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
