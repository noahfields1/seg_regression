# %%
import numpy as np
import pandas as pd
import matplotlib

import os
import sys

sys.path.append(os.path.abspath('..'))
from modules import vascular_data as sv
import vtk

# %%
files = [
"/home/marsdenlab/projects/SV/UQ/data/0144/coarse/0/aorta_cap.vtp",
"/home/marsdenlab/projects/SV/UQ/data/0144/coarse/0/ext_iliac_left_cap.vtp",
"/home/marsdenlab/projects/SV/UQ/data/0144/coarse/0/celiac_splenic_cap.vtp"
]

pds = []
for fn in files:
    pd = sv.vtk_read_polydata(fn)
    pd = sv.vtk_clean_polydata(pd)
    pds.append(pd)
    
print(pds[0])
# Out:
# vtkPolyData (0x5651054d9180)
#   Debug: Off
#   Modified Time: 3167
#   Reference Count: 1
#   Registered Events: (none)
#   Information: 0x5651053b3550
#   Data Released: False
#   Global Release Data: Off
#   UpdateTime: 3186
#   Field Data:
#     Debug: Off
#     Modified Time: 3058
#     Reference Count: 1
#     Registered Events: (none)
#     Number Of Arrays: 0
#     Number Of Components: 0
#     Number Of Tuples: 0
#   Number Of Points: 6000
#   Number Of Cells: 11996
#   Cell Data:
#     Debug: Off
#     Modified Time: 3161
#     Reference Count: 1
#     Registered Events:
#       Registered Observers:
#         vtkObserver (0x5651053c3370)
#           Event: 33
#           EventName: ModifiedEvent
#           Command: 0x5651054c83b0
#           Priority: 0
#           Tag: 1
#     Number Of Arrays: 2
#     Array 0 name = CapID
#     Array 1 name = Normals
#     Number Of Components: 4
#     Number Of Tuples: 11996
#     Copy Tuple Flags: ( 1 1 1 1 1 0 1 1 )
# ...

# %%
pd1 = sv.vtk_merge_polydata(pds[0],pds[2],"union")
pd2 = sv.vtk_merge_polydata(pd1,pds[1],"union")

# %%
print(pd1)
print(pd2)
# Out:
# vtkPolyData (0x5651051cb1a0)
#   Debug: Off
#   Modified Time: 541298
#   Reference Count: 1
#   Registered Events: (none)
#   Information: 0x5651053ddce0
#   Data Released: False
#   Global Release Data: Off
#   UpdateTime: 541853
#   Field Data:
#     Debug: Off
#     Modified Time: 541280
#     Reference Count: 1
#     Registered Events: (none)
#     Number Of Arrays: 0
#     Number Of Components: 0
#     Number Of Tuples: 0
#   Number Of Points: 12153
#   Number Of Cells: 23588
#   Cell Data:
#     Debug: Off
#     Modified Time: 541242
#     Reference Count: 1
#     Registered Events:
#       Registered Observers:
#         vtkObserver (0x565105537720)
#           Event: 33
#           EventName: ModifiedEvent
#           Command: 0x5651053ddc90
#           Priority: 0
#           Tag: 1
#     Number Of Arrays: 4
#     Array 0 name = BoundaryCells
#     Array 1 name = BooleanRegion
#     Array 2 name = BadTriangle
#     Array 3 name = FreeEdge
#     Number Of Components: 4
# ...

# %%
output_files = [
    "/home/marsdenlab/projects/SV/UQ/data/0144/coarse/0/merge1.vtp",
    "/home/marsdenlab/projects/SV/UQ/data/0144/coarse/0/merge2.vtp"
]

output_pds = [pd1,pd2]

for pd,o_fn in zip(output_pds,output_files):
    sv.vtk_write_polydata(pd,o_fn)
